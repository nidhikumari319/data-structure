# %% [markdown]
# # 1. Discuss string slicing and provide examples.
#
# ans:
#
# Specify the start index ,  end index and the step index , separated by a colon, to return a part of the string.
#
# string[start:end:step]
#
# ## example:
#
# a="pwskills"
#
# a[0:8]
#
# a[2:7]
#
# # 2. Explain the key features of lists in Python.
#
# ans:
#
# 1.Mutable: You can modify the list after its creation.
#
# 2.Ordered: Lists maintain the order of elements.
#
# 3.Heterogeneous: A list can contain elements of different types (e.g., integers, strings, objects).
#
# 4.Dynamic sizing: The size of the list can be changed as elements are added or removed.
#
# 5.Indexing and slicing: Lists support indexing and slicing operations.
#
#
# # 3. Describe how to access, modify, and delete elements in a list with examples
# ans:
#
# ## access the list
#
# a=[12,34,56,67]
#
# print(a[1])
#
# ## modify the list
#
# a=[12,34,56,67]
#
# a[2]="23"
#
# print(a)
#
# ## deleting element in the list using .clear()
#
# a=[12,34,56,67]
#
# a.remove(12)
#
# print(a)
#
#
# a=[12,34,56,67]
#
# a.pop()
#
# print(a)
#
#
# a=[12,34,56,67]
#
# a.pop(3)
#
# print(a)
#
#
# # 4. Compare and contrast tuples and lists with examples.
#
# ans:
#
# list: it is mutable , its syntax is square bracket [] ,it's performance  is slow due to mutablity.
#
# tuple: it is immutable , its syntax is Parentheses (),  it's performance  is faster due to immutablity.
#
# # 5. Describe the key features of sets and provide examples of their use.
#
# ans:
# 1.Unordered: Sets do not maintain order.
#
# 2.Mutable: Elements can be added or removed from a set.
#
# 3.Unique elements: Sets automatically discard duplicate elements.
#
# 4.Set operations: They support operations like union, intersection, and difference.
#
# ## example of unordered:
#
# a={12,3.4,"set",1,3,4,(12,34)}
#
# print(a)
#
# ## example of mutable:
#
# a={12,3.4,"set",1,3,4,(12,34)}
#
# a.add("shyam")
#
# print(a)
#
#
#
# a={12,3.4,"set",1,3,4,(12,34)}
#
# a.remove((12,34))
#
# print(a)
#
# ## example of unique element:
#
# a={1,2,3,5,1,2,3}
#
# print(a)
#
# ## example of unique element:
#
# a={1,2,"ram","shyam","nidhi"}
#
# b={"ram", "ajay", 1,2}
#
# c=a&b
#
# print(c)
#
# ## example of unique element:
#
# a={1,2,"ram","shyam","nidhi"}
#
# b={"ram", "ajay", 1,2}
#
# c=a|b
#
# print(c)
#
# ## example of unique element:
#
# a={1,2,"ram","shyam","nidhi"}
#
# b={"ram", "ajay", 1,2}
#
# c=a-b
#
# print(c)
#
# ## example of unique element:
#
# a={1,2,"ram","shyam","nidhi"}
#
# b={"ram", "ajay", 1,2}
#
# c=a^b
#
# print(c)
#
# # 6. Discuss the use cases of tuples and sets in Python programming.
#
# ans:
#
# ## use case of tuples:
#
# tuple as a data structure where you can't modify data
#
# empid=(1,2,3,4,5)
#
# empid[0]= 34
#
# print(empid)
#
# ## use case of set:
#
# common use cases are operation of set
#
# #use case>>>>>>>>>>>>>
#
# list1=[1,2,3,4, "brinjal","brinjal","apple","apple"]
#
# list1
#
# #if you want to convert this list into set
#
# set(list1)
#
# # 7. Describe how to add, modify, and delete items in a dictionary with examples.
# ans:
#
# ## adding items in dictonary
#
# a={"class":12, "rollno.": 4, "name":"ajay"}
#
# a["phone_no"]=["123456"]
#
# print(a)
#
# ## modifying the items in dictonary
#
# a={"class":12, "rollno": 4, "name":"ajay"}
#
# a["rollno"]= "45"
#
# print(a)
#
# ## delete the items in dictonary:
#
# a={"class":12, "rollno": 4, "name":"ajay"}
#
# a.pop("name")
#
# print(a)
#
#           OR
#
# a={"class":12, "rollno": 4, "name":"ajay"}
#
# del a["name"]
#
# print(a)
#
#
# # 8. Discuss the importance of dictionary keys being immutable and provide examples.
#
# ans:
#
# Dictionary keys must be immutable because they are hashed to find their corresponding values quickly. hash-based( it means to quickly find or store values in a dictionary)
#
# only key and numbers can be used as a key of the dictonary
#
# # example
#
# rules for defining keys
#
# d={1:"key"} #integer as key
# print(d)
#
#
# d={4.5:"key"}
# print(d)
#
#
# d={True:"key"} ##bollean value can also be key of dictonary
# print(d)
